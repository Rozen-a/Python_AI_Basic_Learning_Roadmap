# %% [markdown]
# # 分类回归实战_依据val_acc使用早停_模型保存
#
# 实战步骤：
#
# 1、加载数据集，理解数据集 fashion_minst
#
# 2、搭建 class NeuralNetwork 模型
#
# 3、设置交叉熵损失函数，SGD 优化器
#
# 4、编写评估函数 evaluating
#
# 5、编写训练函数 train
#
# 6、开始训练 训练多少次
#
# 7、绘制损失、准确率曲线

# %% [markdown]
# ## 1. 数据集预处理

# %%
# 计算数据集的均值和标准差
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

# 首先加载数据（仅转换为Tensor，不进行其他预处理）
temp_transform = transforms.ToTensor()
temp_train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=temp_transform)
temp_train_loader = DataLoader(temp_train_dataset, batch_size=64, shuffle=False)

# 初始化累加器
sum_pixels = 0.0
sum_squared_pixels = 0.0
total_pixels = 0

# 遍历所有数据计算均值和平方均值
print("正在计算训练集的均值和标准差...")
for images, _ in temp_train_loader:
    # images形状: [batch_size, 1, 28, 28]
    # 将所有像素值展平为一维
    pixels = images.view(-1)  # [batch_size * 1 * 28 * 28]
    
    # 累加所有像素值和像素值的平方
    sum_pixels += pixels.sum().item()
    sum_squared_pixels += (pixels ** 2).sum().item()
    total_pixels += pixels.numel()

# 计算总体均值 μ = (1/n) * Σ(x_i)
mean = sum_pixels / total_pixels

# 根据公式计算方差：σ² = (1/n) * Σ(x_i²) - μ²
mean_squared = sum_squared_pixels / total_pixels
variance = mean_squared - mean ** 2

# 计算标准差 σ = √σ²
std = variance ** 0.5

print(f"总像素数: {total_pixels}")
print(f"训练集均值 (μ): {mean:.6f}")
print(f"训练集标准差 (σ): {std:.6f}")
print(f"训练集方差 (σ²): {variance:.6f}")
print(f"\n验证计算:")
print(f"  (1/n) * Σ(x_i²) = {mean_squared:.6f}")
print(f"  μ² = {mean**2:.6f}")
print(f"  σ² = (1/n) * Σ(x_i²) - μ² = {mean_squared:.6f} - {mean**2:.6f} = {variance:.6f}")

# 保存均值和标准差供后续使用
dataset_mean = mean
dataset_std = std
# Out:
# 正在计算训练集的均值和标准差...
# 总像素数: 47040000
# 训练集均值 (μ): 0.286041
# 训练集标准差 (σ): 0.353024
# 训练集方差 (σ²): 0.124626
#
# 验证计算:
#   (1/n) * Σ(x_i²) = 0.206445
#   μ² = 0.081819
#   σ² = (1/n) * Σ(x_i²) - μ² = 0.206445 - 0.081819 = 0.124626

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

# 定义数据预处理：将图像转换为Tensor，并进行标准化
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为Tensor并归一化到[0, 1]
    transforms.Normalize(mean=[dataset_mean], std=[dataset_std])  # 标准化
])

# 加载数据集
train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# 定义DataLoader参数
batch_size = 64

# 创建DataLoader对数据进行分批
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 示例：打印一个batch的形状
images, labels = next(iter(train_loader))
print("训练集一个batch的图像形状:", images.shape)
print("训练集一个batch的标签形状:", labels.shape)
print(f"标准化后的数据统计:")
print(f"  均值: {images.mean().item():.6f}")
print(f"  标准差: {images.std().item():.6f}")
print(f"  最小值: {images.min().item():.6f}")
print(f"  最大值: {images.max().item():.6f}")

print("\n第一个batch中的第一个tensor（标准化后）：")
print(images[0])
# Out:
# 训练集一个batch的图像形状: torch.Size([64, 1, 28, 28])
# 训练集一个batch的标签形状: torch.Size([64])
# 标准化后的数据统计:
#   均值: 0.073983
#   标准差: 1.029736
#   最小值: -0.810258
#   最大值: 2.022409
#
# 第一个batch中的第一个tensor（标准化后）：
# tensor([[[-8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01,
-01,
#           -8.1026e-01, -8.1026e-01, -8.1026e-01],
#          [-8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01, -7.9915e-01,
#           -8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01,
#           -8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01,
#           -8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01,
#           -8.1026e-01, -8.1026e-01, -8.1026e-01, -8.1026e-01, -6.8806e-01,
#           -8.1026e-01, -8.1026e-01, -8.1026e-01]]])

# %% [markdown]
# ## 2. 搭建模型

# %%
from torch import nn

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()  # 展平输入，[batch, 1, 28, 28] -> [batch, 28*28]
        
        # 先初始化 Sequential
        self.network = nn.Sequential()
        
        # 第1层：784 -> 100
        self.network.add_module('fc1', nn.Linear(28*28, 100))
        self.network.add_module('relu1', nn.ReLU())
        
        # 使用循环动态添加网络层
        # 中间18层，每层都是100 -> 100
        for i in range(18):
            self.network.add_module(f'fc{i+2}', nn.Linear(100, 100))
            self.network.add_module(f'relu{i+2}', nn.ReLU())
        
        # 输出层：100 -> 10（不需要激活函数）
        self.network.add_module('fc20', nn.Linear(100, 10))

    # 前向传播方法，调用 model(x) 会自动调用 forward(x)
    def forward(self, x):
        x = self.flatten(x)  # 展平输入
        x = self.network(x)  # 自动按顺序依次执行每一层
        return x

# %%
# 模型测试

# 随机生成一个数据，形状为 (1, 1, 28, 28)
random_input = torch.randn(1, 1, 28, 28)

# 实例化模型
model = NeuralNetwork()

# 调用模型进行前向传播
output = model(random_input)

print("模型输出：")
print(output)
# Out:
# 模型输出：
# tensor([[ 0.0527,  0.0272,  0.1388, -0.0026,  0.0285, -0.0478, -0.0363,  0.0392,
#          -0.0082, -0.0580]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## 3. 封装Trainer类进行训练与评估

# %%
# 导入 Trainer 模块
from Train_v3 import Trainer  # Train_v3添加早停功能和模型保存功能
import torch.optim as optim
import os

# 创建新的模型实例（如果之前已经训练过，可以创建新模型重新训练）
model_with_trainer = NeuralNetwork()

# 设置保存路径：checkpoints文件夹下的与本文件同名（不含扩展名）文件夹
notebook_name = 'classification_5'
save_dir = f'./checkpoints/{notebook_name}'
model_name = notebook_name

# 创建 Trainer 实例，传入模型和数据加载器
trainer = Trainer(
    model=model_with_trainer,
    train_loader=train_loader,
    val_loader=test_loader,
    early_stopping=True,  # 启用早停
    patience=5,  # 早停耐心值
    monitor='val_acc',  # 依据val_acc早停
    min_delta=0.001,  # 最小改善幅度
    restore_best_weights=True,  # 恢复最佳模型权重
    save_best_model=True,  # 保存最佳模型
    save_dir=save_dir,  # 保存目录
    model_name=model_name  # 模型名称
)

# 开始训练（使用 Trainer 类）
num_epochs = 40
trainer.train(num_epochs=num_epochs)

# 使用 Trainer 进行最终评估
print("\n" + "=" * 60)
print("最终模型评估")
print("=" * 60)
final_loss, final_acc = trainer.evaluating()
print(f"最终测试损失: {final_loss:.4f}")
print(f"最终测试准确率: {final_acc:.4f}")

# 使用 Trainer 绘制训练历史曲线
trainer.plot_history()
# Out:
# ============================================================
# Trainer 初始化完成
# ============================================================
# 设备: cuda
# 损失函数: CrossEntropyLoss()
# 优化器: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# 训练集: 60000 个样本, 938 个批次
# 验证集: 10000 个样本, 157 个批次
# 早停: 启用 (patience=5, monitor=val_acc, min_delta=0.001)
# 模型保存: 保存最佳模型 (保存目录: ./checkpoints/classification_5)
# ============================================================
#
# ============================================================
# 开始训练模型
# ============================================================
# 训练轮数: 40
# 训练集: 60000 个样本, 938 个批次
# 验证集: 10000 个样本, 157 个批次
# 设备: cuda
# 优化器: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# 早停: 启用 (patience=5, monitor=val_acc, min_delta=0.001)
# 模型保存: 保存最佳模型 (保存目录: ./checkpoints/classification_5)
# ============================================================
#
# Epoch [1/40], Train Loss: 2.3031, Train Acc: 0.1015, Val Loss: 2.3031, Val Acc: 0.1000
# Epoch [2/40], Train Loss: 2.3032, Train Acc: 0.0970, Val Loss: 2.3029, Val Acc: 0.1000
# Epoch [3/40], Train Loss: 2.3032, Train Acc: 0.0970, Val Loss: 2.3029, Val Acc: 0.1000
# Epoch [4/40], Train Loss: 2.3031, Train Acc: 0.0984, Val Loss: 2.3030, Val Acc: 0.1000
# Epoch [5/40], Train Loss: 2.3031, Train Acc: 0.0983, Val Loss: 2.3029, Val Acc: 0.1000
#
# 早停触发！验证指标连续 5 个epoch没有改善
# 最佳轮数: 1, 最佳val_acc: 0.1000
# 已恢复最佳模型权重
#
# ============================================================
# 训练提前结束（早停）！
# ============================================================
# 总训练轮数(实际轮数/计划轮数): 6/40
# 最佳轮数: 1
# 最佳验证准确率: 0.1000
# 最终训练损失: 2.3032
# 最终训练准确率: 0.0981
# 最终验证损失: 2.3028
# 最终验证准确率: 0.1000
# ============================================================
# 模型已保存: ./checkpoints/classification_5\classification_5_best.pth
#
# ============================================================
# 最终模型评估
# ============================================================
#
# 开始评估模型...
# 评估数据集: 10000 个样本, 157 个批次
# 评估完成 - 损失: 2.3028, 准确率: 0.1000 (1000/10000)
# 最终测试损失: 2.3028
# 最终测试准确率: 0.1000
#
# ============================================================
# 开始绘制训练历史曲线
# ============================================================
# 训练轮数: 6
# 图像大小: (16, 5)
# ============================================================
# 训练历史曲线绘制完成！
# ============================================================

# %% [markdown]
# ### 训练结果问题分析
#
# 梯度消失：20层全连接网络，没有批归一化，反向传播时梯度会逐渐消失
#
# 训练不收敛：Loss 约 2.303（10分类的随机猜测值），准确率约 10%（随机水平）
#
# 模型未学习：参数几乎不更新
#
# ### 解决方案
#
# 在每层全连接层后添加 BatchNorm1d：
# - 稳定训练过程
# - 缓解梯度消失
# - 允许使用更大的学习率
# - 提供一定的正则化效果
#
# ### 修改内容
# 网络结构变为：Linear → BatchNorm → ReLU → Linear → BatchNorm → ReLU → ...
#
# 每层顺序：全连接层 → 批归一化 → ReLU激活
#
# 重新训练后，模型应能正常学习。
#
# 批归一化有助于：
# - 加速收敛
# - 提高训练稳定性
# - 改善最终性能

# %%
# 重新定义带批归一化的模型类
from torch import nn

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()  # 展平输入，[batch, 1, 28, 28] -> [batch, 28*28]
        
        # 先初始化 Sequential
        self.network = nn.Sequential()
        
        # 第1层：784 -> 100，添加批归一化防止梯度消失
        self.network.add_module('fc1', nn.Linear(28*28, 100))
        self.network.add_module('bn1', nn.BatchNorm1d(100))  # 批归一化
        self.network.add_module('relu1', nn.ReLU())
        
        # 使用循环动态添加网络层
        # 中间18层，每层都是100 -> 100，每层都添加批归一化
        for i in range(18):
            self.network.add_module(f'fc{i+2}', nn.Linear(100, 100))
            self.network.add_module(f'bn{i+2}', nn.BatchNorm1d(100))  # 批归一化
            self.network.add_module(f'relu{i+2}', nn.ReLU())
        
        # 输出层：100 -> 10（不需要激活函数和批归一化）
        self.network.add_module('fc20', nn.Linear(100, 10))

    # 前向传播方法，调用 model(x) 会自动调用 forward(x)
    def forward(self, x):
        x = self.flatten(x)  # 展平输入
        x = self.network(x)  # 自动按顺序依次执行每一层
        return x

# 导入 Trainer 模块
from Train_v3 import Trainer
import torch.optim as optim
import os

# 创建新的模型实例（带批归一化）
model_with_trainer = NeuralNetwork()

# 设置保存路径：checkpoints文件夹下的与本文件同名（不含扩展名）文件夹
notebook_name = 'classification_5_bn'  # 使用新的名称区分带批归一化的模型
save_dir = f'./checkpoints/{notebook_name}'
model_name = notebook_name

# 创建 Trainer 实例，传入模型和数据加载器
trainer = Trainer(
    model=model_with_trainer,
    train_loader=train_loader,
    val_loader=test_loader,
    early_stopping=True,  # 启用早停
    patience=5,  # 早停耐心值
    monitor='val_acc',  # 依据val_acc早停
    min_delta=0.001,  # 最小改善幅度
    restore_best_weights=True,  # 恢复最佳模型权重
    save_best_model=True,  # 保存最佳模型
    save_every_epoch=True,  # 每个epoch都保存
    save_dir=save_dir,  # 保存目录
    model_name=model_name  # 模型名称
)

# 开始训练（使用 Trainer 类）
num_epochs = 40
trainer.train(num_epochs=num_epochs)

# 使用 Trainer 进行最终评估
print("\n" + "=" * 60)
print("最终模型评估")
print("=" * 60)
final_loss, final_acc = trainer.evaluating()
print(f"最终测试损失: {final_loss:.4f}")
print(f"最终测试准确率: {final_acc:.4f}")

# 使用 Trainer 绘制训练历史曲线
trainer.plot_history()
# Out:
# ============================================================
# Trainer 初始化完成
# ============================================================
# 设备: cuda
# 损失函数: CrossEntropyLoss()
# 优化器: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# 训练集: 60000 个样本, 938 个批次
# 验证集: 10000 个样本, 157 个批次
# 早停: 启用 (patience=5, monitor=val_acc, min_delta=0.001)
# 模型保存: 保存最佳模型 (保存目录: ./checkpoints/classification_5_bn)
# 模型保存: 每个epoch都保存 (保存目录: ./checkpoints/classification_5_bn)
# ============================================================
#
# ============================================================
# 开始训练模型
# ============================================================
# 训练轮数: 40
# 训练集: 60000 个样本, 938 个批次
# 验证集: 10000 个样本, 157 个批次
# 设备: cuda
# 优化器: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# 早停: 启用 (patience=5, monitor=val_acc, min_delta=0.001)
# 模型保存: 保存最佳模型 (保存目录: ./checkpoints/classification_5_bn)
# 模型保存: 每个epoch都保存 (保存目录: ./checkpoints/classification_5_bn)
# ============================================================
#
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0001.pth
# Epoch [1/40], Train Loss: 0.7760, Train Acc: 0.7165, Val Loss: 0.5499, Val Acc: 0.7997
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0002.pth
# Epoch [2/40], Train Loss: 0.5270, Train Acc: 0.8130, Val Loss: 0.4722, Val Acc: 0.8372
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0003.pth
# Epoch [3/40], Train Loss: 0.4601, Train Acc: 0.8355, Val Loss: 0.4285, Val Acc: 0.8479
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0004.pth
# Epoch [4/40], Train Loss: 0.4164, Train Acc: 0.8514, Val Loss: 0.4188, Val Acc: 0.8566
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0005.pth
# Epoch [5/40], Train Loss: 0.4032, Train Acc: 0.8558, Val Loss: 0.4258, Val Acc: 0.8595
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0006.pth
# Epoch [6/40], Train Loss: 0.3741, Train Acc: 0.8668, Val Loss: 0.4071, Val Acc: 0.8516
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0007.pth
# Epoch [7/40], Train Loss: 0.3573, Train Acc: 0.8703, Val Loss: 0.4199, Val Acc: 0.8517
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0008.pth
# Epoch [8/40], Train Loss: 0.3490, Train Acc: 0.8755, Val Loss: 0.4556, Val Acc: 0.8377
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0009.pth
# Epoch [9/40], Train Loss: 0.3366, Train Acc: 0.8793, Val Loss: 0.3703, Val Acc: 0.8700
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0010.pth
# Epoch [10/40], Train Loss: 0.3259, Train Acc: 0.8826, Val Loss: 0.3802, Val Acc: 0.8717
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0011.pth
# Epoch [11/40], Train Loss: 0.3175, Train Acc: 0.8857, Val Loss: 0.3861, Val Acc: 0.8679
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0012.pth
# Epoch [12/40], Train Loss: 0.3079, Train Acc: 0.8897, Val Loss: 0.3579, Val Acc: 0.8753
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0013.pth
# Epoch [13/40], Train Loss: 0.2995, Train Acc: 0.8924, Val Loss: 0.4096, Val Acc: 0.8527
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0014.pth
# Epoch [14/40], Train Loss: 0.2993, Train Acc: 0.8941, Val Loss: 0.3501, Val Acc: 0.8767
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0015.pth
# Epoch [15/40], Train Loss: 0.2883, Train Acc: 0.8964, Val Loss: 0.3465, Val Acc: 0.8757
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0016.pth
# Epoch [16/40], Train Loss: 0.2812, Train Acc: 0.8985, Val Loss: 0.3478, Val Acc: 0.8779
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0017.pth
# Epoch [17/40], Train Loss: 0.2730, Train Acc: 0.9005, Val Loss: 0.3295, Val Acc: 0.8807
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0018.pth
# Epoch [18/40], Train Loss: 0.2721, Train Acc: 0.9014, Val Loss: 0.3318, Val Acc: 0.8819
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0019.pth
# Epoch [19/40], Train Loss: 0.2609, Train Acc: 0.9045, Val Loss: 0.3319, Val Acc: 0.8814
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0020.pth
# Epoch [20/40], Train Loss: 0.2607, Train Acc: 0.9059, Val Loss: 0.3543, Val Acc: 0.8739
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0021.pth
# Epoch [21/40], Train Loss: 0.2550, Train Acc: 0.9074, Val Loss: 0.3369, Val Acc: 0.8787
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_epoch_0022.pth
# Epoch [22/40], Train Loss: 0.2491, Train Acc: 0.9118, Val Loss: 0.3334, Val Acc: 0.8826
#
# 早停触发！验证指标连续 5 个epoch没有改善
# 最佳轮数: 18, 最佳val_acc: 0.8819
# 已恢复最佳模型权重
#
# ============================================================
# 训练提前结束（早停）！
# ============================================================
# 总训练轮数(实际轮数/计划轮数): 23/40
# 最佳轮数: 18
# 最佳验证准确率: 0.8819
# 最终训练损失: 0.2441
# 最终训练准确率: 0.9117
# 最终验证损失: 0.3338
# 最终验证准确率: 0.8823
# ============================================================
# 模型已保存: ./checkpoints/classification_5_bn\classification_5_bn_best.pth
#
# ============================================================
# 最终模型评估
# ============================================================
#
# 开始评估模型...
# 评估数据集: 10000 个样本, 157 个批次
# 评估完成 - 损失: 0.3338, 准确率: 0.8823 (8823/10000)
# 最终测试损失: 0.3338
# 最终测试准确率: 0.8823
#
# ============================================================
# 开始绘制训练历史曲线
# ============================================================
# 训练轮数: 23
# 图像大小: (16, 5)
# ============================================================
# 训练历史曲线绘制完成！
# ============================================================
