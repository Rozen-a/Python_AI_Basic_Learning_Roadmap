# %% [markdown]
# # 分类回归实战_依据val_acc使用早停_模型保存
#
# 实战步骤：
#
# 1、加载数据集，理解数据集 fashion_minst
#
# 2、搭建 class NeuralNetwork 模型
#
# 3、设置交叉熵损失函数，SGD 优化器
#
# 4、编写评估函数 evaluating
#
# 5、编写训练函数 train
#
# 6、开始训练 训练多少次
#
# 7、绘制损失、准确率曲线

# %% [markdown]
# ## 1. 数据集预处理

# %%
# 计算数据集的均值和标准差
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

# 首先加载数据（仅转换为Tensor，不进行其他预处理）
temp_transform = transforms.ToTensor()
temp_train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=temp_transform)
temp_train_loader = DataLoader(temp_train_dataset, batch_size=64, shuffle=False)

# 初始化累加器
sum_pixels = 0.0
sum_squared_pixels = 0.0
total_pixels = 0

# 遍历所有数据计算均值和平方均值
print("正在计算训练集的均值和标准差...")
for images, _ in temp_train_loader:
    # images形状: [batch_size, 1, 28, 28]
    # 将所有像素值展平为一维
    pixels = images.view(-1)  # [batch_size * 1 * 28 * 28]
    
    # 累加所有像素值和像素值的平方
    sum_pixels += pixels.sum().item()
    sum_squared_pixels += (pixels ** 2).sum().item()
    total_pixels += pixels.numel()

# 计算总体均值 μ = (1/n) * Σ(x_i)
mean = sum_pixels / total_pixels

# 根据公式计算方差：σ² = (1/n) * Σ(x_i²) - μ²
mean_squared = sum_squared_pixels / total_pixels
variance = mean_squared - mean ** 2

# 计算标准差 σ = √σ²
std = variance ** 0.5

print(f"总像素数: {total_pixels}")
print(f"训练集均值 (μ): {mean:.6f}")
print(f"训练集标准差 (σ): {std:.6f}")
print(f"训练集方差 (σ²): {variance:.6f}")
print(f"\n验证计算:")
print(f"  (1/n) * Σ(x_i²) = {mean_squared:.6f}")
print(f"  μ² = {mean**2:.6f}")
print(f"  σ² = (1/n) * Σ(x_i²) - μ² = {mean_squared:.6f} - {mean**2:.6f} = {variance:.6f}")

# 保存均值和标准差供后续使用
dataset_mean = mean
dataset_std = std
# Out:
# 正在计算训练集的均值和标准差...
# 总像素数: 47040000
# 训练集均值 (μ): 0.286041
# 训练集标准差 (σ): 0.353024
# 训练集方差 (σ²): 0.124626
#
# 验证计算:
#   (1/n) * Σ(x_i²) = 0.206445
#   μ² = 0.081819
#   σ² = (1/n) * Σ(x_i²) - μ² = 0.206445 - 0.081819 = 0.124626

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

# 定义数据预处理：将图像转换为Tensor，并进行标准化
transform = transforms.Compose([
    transforms.ToTensor(),  # 转换为Tensor并归一化到[0, 1]
    transforms.Normalize(mean=[dataset_mean], std=[dataset_std])  # 标准化
])

# 加载数据集
train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# 定义DataLoader参数
batch_size = 64

# 创建DataLoader对数据进行分批
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## 2. 搭建模型

# %%
from torch import nn

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()  # 展平输入，[batch, 1, 28, 28] -> [batch, 28*28]
        
        # 先初始化 Sequential
        self.network = nn.Sequential()
        
        # 第1层：784 -> 100
        self.network.add_module('fc1', nn.Linear(28*28, 100))
        self.network.add_module('selu1', nn.SELU())
        # 在第一层后加入AlphaDropout
        self.network.add_module('alphadropout1', nn.AlphaDropout(p=0.1))
        
        # 使用循环动态添加网络层
        # 中间18层，每层都是100 -> 100
        for i in range(18):
            self.network.add_module(f'fc{i+2}', nn.Linear(100, 100))
            self.network.add_module(f'selu{i+2}', nn.SELU())
        
        # 输出层：100 -> 10（不需要激活函数）
        self.network.add_module('fc20', nn.Linear(100, 10))

    # 前向传播方法，调用 model(x) 会自动调用 forward(x)
    def forward(self, x):
        x = self.flatten(x)  # 展平输入
        x = self.network(x)  # 自动按顺序依次执行每一层
        return x

# %%
# 模型测试

# 随机生成一个数据，形状为 (1, 1, 28, 28)
random_input = torch.randn(1, 1, 28, 28)

# 实例化模型
model = NeuralNetwork()

# 调用模型进行前向传播
output = model(random_input)

print("模型输出：")
print(output)
# Out:
# 模型输出：
# tensor([[-0.0233,  0.0140, -0.0921,  0.1148,  0.0337,  0.0147,  0.1231,  0.1416,
#           0.0006, -0.1126]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## 3. 封装Trainer类进行训练与评估

# %%
# 导入 Trainer 模块
from Train_v3 import Trainer  # Train_v3添加早停功能和模型保存功能
import torch.optim as optim
import os

# 创建新的模型实例（如果之前已经训练过，可以创建新模型重新训练）
model_with_trainer = NeuralNetwork()

# 设置保存路径
notebook_name = 'classification_7'
save_dir = f'./checkpoints/{notebook_name}'
model_name = notebook_name

# 创建 Trainer 实例，传入模型和数据加载器
trainer = Trainer(
    model=model_with_trainer,
    train_loader=train_loader,
    val_loader=test_loader,
    early_stopping=True,  # 启用早停
    patience=5,  # 早停耐心值
    monitor='val_acc',  # 依据val_acc早停
    min_delta=0.001,  # 最小改善幅度
    restore_best_weights=True,  # 恢复最佳模型权重
    save_best_model=True,  # 保存最佳模型
    save_dir=save_dir,  # 保存目录
    model_name=model_name  # 模型名称
)

# 开始训练（使用 Trainer 类）
num_epochs = 40
trainer.train(num_epochs=num_epochs)

# 使用 Trainer 进行最终评估
print("\n" + "=" * 60)
print("最终模型评估")
print("=" * 60)
final_loss, final_acc = trainer.evaluating()
print(f"最终测试损失: {final_loss:.4f}")
print(f"最终测试准确率: {final_acc:.4f}")

# 使用 Trainer 绘制训练历史曲线
trainer.plot_history()
# Out:
# ============================================================
# Trainer 初始化完成
# ============================================================
# 设备: cuda
# 损失函数: CrossEntropyLoss()
# 优化器: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# 模型名称: classification_7
# 训练集: 60000 个样本, 938 个批次
# 验证集: 10000 个样本, 157 个批次
# 早停: 启用 (patience=5, monitor=val_acc, min_delta=0.001)
# 模型保存: 保存最佳模型 (保存目录: ./checkpoints/classification_7)
# ============================================================
#
# ============================================================
# 开始训练模型
# ============================================================
# 训练轮数: 40
# 训练集: 60000 个样本, 938 个批次
# 验证集: 10000 个样本, 157 个批次
# 设备: cuda
# 优化器: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )
# 早停: 启用 (patience=5, monitor=val_acc, min_delta=0.001)
# 模型保存: 保存最佳模型 (保存目录: ./checkpoints/classification_7)
# ============================================================
#
# Epoch [1/40], Train Loss: 1.0532, Train Acc: 0.5836, Val Loss: 0.6714, Val Acc: 0.7726
# Epoch [2/40], Train Loss: 0.5943, Train Acc: 0.7919, Val Loss: 0.5589, Val Acc: 0.8117
# Epoch [3/40], Train Loss: 0.5151, Train Acc: 0.8268, Val Loss: 0.4904, Val Acc: 0.8289
# Epoch [4/40], Train Loss: 0.4522, Train Acc: 0.8464, Val Loss: 0.5276, Val Acc: 0.8322
# Epoch [5/40], Train Loss: 0.4199, Train Acc: 0.8565, Val Loss: 0.4595, Val Acc: 0.8325
# Epoch [6/40], Train Loss: 0.4003, Train Acc: 0.8609, Val Loss: 0.4344, Val Acc: 0.8472
# Epoch [7/40], Train Loss: 0.3815, Train Acc: 0.8664, Val Loss: 0.4179, Val Acc: 0.8595
# Epoch [8/40], Train Loss: 0.3707, Train Acc: 0.8706, Val Loss: 0.4242, Val Acc: 0.8550
# Epoch [9/40], Train Loss: 0.3548, Train Acc: 0.8759, Val Loss: 0.3894, Val Acc: 0.8656
# Epoch [10/40], Train Loss: 0.3457, Train Acc: 0.8784, Val Loss: 0.3944, Val Acc: 0.8651
# Epoch [11/40], Train Loss: 0.3368, Train Acc: 0.8800, Val Loss: 0.3784, Val Acc: 0.8742
# Epoch [12/40], Train Loss: 0.3288, Train Acc: 0.8845, Val Loss: 0.3909, Val Acc: 0.8678
# Epoch [13/40], Train Loss: 0.3305, Train Acc: 0.8846, Val Loss: 0.3856, Val Acc: 0.8739
# Epoch [14/40], Train Loss: 0.3144, Train Acc: 0.8904, Val Loss: 0.3813, Val Acc: 0.8735
# Epoch [15/40], Train Loss: 0.3079, Train Acc: 0.8915, Val Loss: 0.3813, Val Acc: 0.8715
# Epoch [16/40], Train Loss: 0.3077, Train Acc: 0.8919, Val Loss: 0.3671, Val Acc: 0.8778
# Epoch [17/40], Train Loss: 0.3005, Train Acc: 0.8942, Val Loss: 0.3718, Val Acc: 0.8787
# Epoch [18/40], Train Loss: 0.2971, Train Acc: 0.8960, Val Loss: 0.3641, Val Acc: 0.8789
# Epoch [19/40], Train Loss: 0.2901, Train Acc: 0.8976, Val Loss: 0.3499, Val Acc: 0.8808
# Epoch [20/40], Train Loss: 0.2899, Train Acc: 0.8979, Val Loss: 0.4014, Val Acc: 0.8690
# Epoch [21/40], Train Loss: 0.2829, Train Acc: 0.9002, Val Loss: 0.3535, Val Acc: 0.8812
# Epoch [22/40], Train Loss: 0.2781, Train Acc: 0.9021, Val Loss: 0.3478, Val Acc: 0.8839
# Epoch [23/40], Train Loss: 0.2765, Train Acc: 0.9025, Val Loss: 0.3560, Val Acc: 0.8844
# Epoch [24/40], Train Loss: 0.2673, Train Acc: 0.9050, Val Loss: 0.3601, Val Acc: 0.8798
# Epoch [25/40], Train Loss: 0.2667, Train Acc: 0.9059, Val Loss: 0.3451, Val Acc: 0.8853
# Epoch [26/40], Train Loss: 0.2626, Train Acc: 0.9059, Val Loss: 0.3644, Val Acc: 0.8852
# Epoch [27/40], Train Loss: 0.2600, Train Acc: 0.9083, Val Loss: 0.3578, Val Acc: 0.8829
# Epoch [28/40], Train Loss: 0.2582, Train Acc: 0.9083, Val Loss: 0.3601, Val Acc: 0.8831
# Epoch [29/40], Train Loss: 0.2521, Train Acc: 0.9108, Val Loss: 0.3632, Val Acc: 0.8773
#
# 早停触发！验证指标连续 5 个epoch没有改善
# 最佳轮数: 25, 最佳val_acc: 0.8853
# 已恢复最佳模型权重
#
# ============================================================
# 训练提前结束（早停）！
# ============================================================
# 总训练轮数(实际轮数/计划轮数): 30/40
# 最佳轮数: 25
# 最佳验证准确率: 0.8853
# 最终训练损失: 0.2482
# 最终训练准确率: 0.9117
# 最终验证损失: 0.3747
# 最终验证准确率: 0.8814
# ============================================================
# 模型已保存: ./checkpoints/classification_7\classification_7_best.pth
#
# ============================================================
# 最终模型评估
# ============================================================
#
# 开始评估模型...
# 评估数据集: 10000 个样本, 157 个批次
# 评估完成 - 损失: 0.3747, 准确率: 0.8814 (8814/10000)
# 最终测试损失: 0.3747
# 最终测试准确率: 0.8814
#
# ============================================================
# 开始绘制训练历史曲线
# ============================================================
# 训练轮数: 30
# 图像大小: (16, 5)
# ============================================================
# 训练历史曲线绘制完成！
# ============================================================

# %% [markdown]
# ### AlphaDropout 参数调整
#
# - 不进行 AlphaDropout：
#
#     总训练轮数(实际轮数/计划轮数): 25/40
#
#     最佳轮数: 20
#
#     最佳验证准确率: 0.8827
#
#     最终训练损失: 0.2331
#
#     最终训练准确率: 0.9192
#
#     最终验证损失: 0.3856
#
#     最终验证准确率: 0.8822
#
# - p = 0.3 ：
#
#     总训练轮数(实际轮数/计划轮数): 25/40
#
#     最佳轮数: 20
#
#     最佳验证准确率: 0.8767
#
#     最终训练损失: 0.3228
#
#     最终训练准确率: 0.8861
#
#     最终验证损失: 0.3891
#
#     最终验证准确率: 0.8699
#
#     - 分析：正则过强导致欠拟合 -> 缩小p值
#
# - p = 0.1 ：
#
#     总训练轮数(实际轮数/计划轮数): 30/40
#
#     最佳轮数: 25
#
#     最佳验证准确率: 0.8853
#
#     最终训练损失: 0.2482
#
#     最终训练准确率: 0.9117
#
#     最终验证损失: 0.3747
#
#     最终验证准确率: 0.8814
#
#     - 分析：训练结果有少许提升，过拟合现象也有所改善

# %% [markdown]
# # Train_v3 修改说明
#
# 最终检查发现打印内容中，触发早停的 epoch 训练及验证结果未被打印，已在 Train_v3.py 代码中修改（行数 406-410），对比 Train_v2 中行数279-283
#
# 由于训练耗时较长，除打印内容外并未发现其他错误，不再对所有代码重新运行修正
